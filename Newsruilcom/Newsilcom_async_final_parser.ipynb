# %%
# !pip install asyncpg loguru dateparser nest_asyncio
# Out:
# Collecting asyncpg
#   Downloading asyncpg-0.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 12.3 MB/s eta 0:00:00
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.3 MB/s eta 0:00:00
# Collecting dateparser
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from asyncpg) (4.0.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser) (2023.4)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser) (2024.5.15)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser) (5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser) (1.16.0)
# Installing collected packages: loguru, asyncpg, dateparser
# Successfully installed asyncpg-0.29.0 dateparser-1.2.0 loguru-0.7.2

# %%
"""
Scraper for asynchronous news gathering from newsru.co.il
Used for non-commercial research purposes
"""
import asyncio
import aiohttp
import asyncpg

from bs4 import BeautifulSoup
import random
from loguru import logger
import dateparser
import datetime as dt
import time
import pickle
import pandas as pd
from typing import List, Optional


# Database connection parameters
import nest_asyncio
nest_asyncio.apply()

# User agents for HTTP requests
user_agents = open('proxy/user-agents.txt').read().splitlines()
random_user_agent = random.choice(user_agents)
headers = {'User-Agent': random_user_agent}

# Database connection parameters
DB_USER = 'DB_USER'
DB_NAME = 'DB_NAME'
DB_PASS = "DB_PASS"
DB_HOST = "DB_HOST"
DB_PORT = 5432


con = f"postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# q = f"SELECT url FROM lenta where news is null"
# links = pd.read_sql(sql=q, con=con).url.tolist()

# List to store links for news articles
site_url: str = 'https://www.newsru.co.il'
links: List[str] = []


def save_list_to_file(my_list: List[str], filename: str) -> None:
    """
    Saves a list to a file using pickle.

    :param my_list: The list to save
    :param filename: The filename to save the list to
    """
    with open(filename, 'wb') as file:
        pickle.dump(my_list, file)
        logger.info(f"List saved successfully to {filename}.")


def load_list_from_file(filename: str) -> List[str]:
    """
    Loads a list from a file using pickle.

    :param filename: The filename to load the list from
    :return: The loaded list
    """
    with open(filename, 'rb') as file:
        loaded_list = pickle.load(file)
        logger.info(f"List loaded successfully from {filename}.")
        return loaded_list


async def write_to_db(url: str, date: Optional[dt.datetime], news: Optional[str], img_url: str, title: Optional[str],
                      page_links: str) -> None:
    """
    Writes the news data to the database.

    :param url: The URL of the news article
    :param date: The publication date of the news article
    :param title: The title of the news article
    :param topic: The topic of the news article
    :param news: The content of the news article
    :param tags: The tags associated with the news article
    """
    conn = await asyncpg.connect(con)
    query = """
    INSERT INTO newsilcom (url, date, news, agency, img_url, title, resume, links, category)
    VALUES ($1, $2, $3, $4, $5, $6, $7, $8, $9)
    """
    values = (
        url,
        date,
        news,
        "newsru.co.il",
        img_url,
        title,
        None,
        page_links,
        None
    )
    await conn.execute(query, *values)
    logger.info(f"{url} записан успешно")
    await conn.close()


async def fetch_page_urls(url: str, session: aiohttp.ClientSession) -> None:
    """
    Fetches URLs of news articles from a given page.

    :param url: The URL of the page to fetch URLs from
    :param session: The aiohttp session for making HTTP requests
    """
    async with session.get(url=url, headers=headers) as response:
        try:
            if response and response.status != 204:
                answer = await response.text()
                soup = BeautifulSoup(answer, features="html.parser")

                news_fields = soup.find(attrs={'class': 'main--tag--list'})
                paragraph = news_fields.find_all(attrs={'class': 'main--tag--list--card--text'})
                date_links = [site_url + text.a.get('href') for text in paragraph]
                links.extend(date_links)

        except AttributeError:
            logger.error(url)


async def fetch_content(url: str, session: aiohttp.ClientSession) -> None:
    """
    Fetches the content of a news article from a given URL.

    :param url: The URL of the news article
    :param session: The aiohttp session for making HTTP requests
    """
    async with session.get(url=url, headers=headers) as response:
        if response and response.status != 204:
            try:
                answer = await response.text()
                soup = BeautifulSoup(answer, features="html.parser")
                news_fields = soup.find(attrs={'class': 'main--single--article'})

                title = news_fields.h1.text
                news = news_fields.find(attrs={'class': 'main--single--article--content--text'}).text.strip()
                img_url = news_fields.find(attrs={'class': 'main--single--article--content--images--item'}).img['src']
                raw_timestamp = \
                news_fields.find(attrs={'class': 'main--single--article--info-text'}).text.strip().split(' |')[0].strip(
                    'время публикации: ')
                date = dateparser.parse(raw_timestamp)
                try:
                    page_links = ', '.join([el.get('href') for el in news_fields.find(attrs={'class': 'main--single--article--content--text'}).find_all('a')])
                except Exception:
                    page_links = ''
                await write_to_db(url=url, date=date, news=news, img_url=img_url, title=title, page_links=page_links)
            except AttributeError:
                logger.error(f'{url} косячный')



def get_all_links(start_parse_date: dt.date, end_parse_date: dt.date) -> None:
    """
    Fetches all links of news articles within a date range.

    :param start_parse_date: The start date for fetching links
    :param end_parse_date: The end date for fetching links
    """
    global next_links
    dates_list = pd.date_range(start=start_parse_date, end=end_parse_date, freq="D").date.tolist()
    top_urls_list = [site_url + '/world/' + el.strftime("%d%b%Y").lower() for el in dates_list]

    asyncio.run(get_async_job(target_urls=top_urls_list, async_func=fetch_page_urls))

    logger.info(f'Всего собрано {len(links)} ссылок')
    save_list_to_file(my_list=links, filename='links_2024.pkl')


async def get_async_job(target_urls: List[str], async_func) -> None:
    """
    Runs asynchronous jobs to fetch data from URLs.

    :param target_urls: The list of URLs to fetch data from
    :param async_func: The asynchronous function to run for each URL
    """
    chunk = 50  # Reduce this if the database complains about too many connections
    tasks = []
    start = 0

    logger.info(f'Начинается сбор новостей')
    times = len(target_urls) // chunk + 1
    for el in range(times):
        logger.info(f'Обработка {el + 1}/{times}')
        async with aiohttp.ClientSession() as session:
            for url in target_urls[start:start + chunk]:
                task = asyncio.create_task(async_func(url, session))
                tasks.append(task)

            await asyncio.gather(*tasks)
            await asyncio.sleep(0.2)
        start += chunk
        tasks = []


if __name__ == '__main__':
    get_all_links(start_parse_date=dt.date(2024, 6, 18), end_parse_date=dt.date(2024, 6, 30))
    if not links:
        links = load_list_from_file('links_2024.pkl')
        # error_urls = load_list_from_file('error_urls.pkl')
        # links = [item for item in links if item not in error_urls]
        # save_list_to_file(my_list=links, filename='links_2024.pkl')
    asyncio.run(get_async_job(target_urls=links, async_func=fetch_content))
# Out:
# 2024-07-01 14:14:47.929 | INFO     | __main__:get_async_job:186 - Начинается сбор новостей
# 2024-07-01 14:14:47.931 | INFO     | __main__:get_async_job:189 - Обработка 1/1
# 2024-07-01 14:14:49.219 | INFO     | __main__:get_all_links:171 - Всего собрано 161 ссылок
# 2024-07-01 14:14:49.222 | INFO     | __main__:save_list_to_file:56 - List saved successfully to links_2024.pkl.
# 2024-07-01 14:14:49.224 | INFO     | __main__:get_async_job:186 - Начинается сбор новостей
# 2024-07-01 14:14:49.227 | INFO     | __main__:get_async_job:189 - Обработка 1/4
# 2024-07-01 14:14:53.561 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/arkansas815.html записан успешно
# 2024-07-01 14:14:53.563 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/ino813.html записан успешно
# 2024-07-01 14:14:53.568 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/hamas_0011.html записан успешно
# 2024-07-01 14:14:53.571 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/canada408.html записан успешно
# 2024-07-01 14:14:53.574 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/ukr_war801.html записан успешно
# 2024-07-01 14:14:53.580 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/ukr_war_107.html записан успешно
# 2024-07-01 14:14:53.583 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/cuba_il_105.html записан успешно
# 2024-07-01 14:14:53.588 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/bolivia_0014.html записан успешно
# 2024-07-01 14:14:53.590 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/ukr_war_109.html записан успешно
# 2024-07-01 14:14:53.592 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/family810.html записан успешно
# 2024-07-01 14:14:53.594 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/ukr_0010.html записан успешно
# 2024-07-01 14:14:53.597 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/arkansas815.html записан успешно
# 2024-07-01 14:14:53.599 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/armenia_pal_113.html записан успешно
# 2024-07-01 14:14:53.600 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/ukr_war_106.html записан успешно
# 2024-07-01 14:14:53.603 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/telangana816.html записан успешно
# 2024-07-01 14:14:53.604 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/german_005.html записан успешно
# 2024-07-01 14:14:53.606 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/ukr_109.html записан успешно
# 2024-07-01 14:14:53.608 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/france802.html записан успешно
# 2024-07-01 14:14:53.609 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/min_ru_121.html записан успешно
# 2024-07-01 14:14:53.611 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/min_ru_116.html записан успешно
# 2024-07-01 14:14:53.612 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/ka29_117.html записан успешно
# 2024-07-01 14:14:53.614 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/min_ru_122.html записан успешно
# 2024-07-01 14:14:53.616 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/min_ru_121.html записан успешно
# 2024-07-01 14:14:53.618 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/eidelman806.html записан успешно
# 2024-07-01 14:14:53.620 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/ukr_108.html записан успешно
# 2024-07-01 14:14:53.621 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/kharkiv821.html записан успешно
# 2024-07-01 14:14:53.623 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/debates_202.html записан успешно
# 2024-07-01 14:14:53.624 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/amur_114.html записан успешно
# 2024-07-01 14:14:53.626 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/icc_004.html записан успешно
# 2024-07-01 14:14:53.627 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/dagestan_126.html записан успешно
# 2024-07-01 14:14:53.629 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/dagestan_110.html записан успешно
# 2024-07-01 14:14:53.631 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/ino813.html записан успешно
# 2024-07-01 14:14:53.633 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/mo816.html записан успешно
# 2024-07-01 14:14:53.634 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/chendu808.html записан успешно
# 2024-07-01 14:14:53.636 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/electr803.html записан успешно
# 2024-07-01 14:14:53.637 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/la_202.html записан успешно
# 2024-07-01 14:14:53.639 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/22jun2024/ukr803.html записан успешно
# 2024-07-01 14:14:53.640 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/pumpyansky.html записан успешно
# 2024-07-01 14:14:53.642 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/tver_110.html записан успешно
# 2024-07-01 14:14:53.643 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/antonio809.html записан успешно
# 2024-07-01 14:14:53.645 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/unrwa409.html записан успешно
# 2024-07-01 14:14:53.646 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/bolivia_108.html записан успешно
# 2024-07-01 14:14:53.648 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/jfna_ua.html записан успешно
# 2024-07-01 14:14:53.728 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/dagestan_101.html записан успешно
# 2024-07-01 14:14:53.763 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/hamas_russia_130.html записан успешно
# 2024-07-01 14:14:53.779 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/il_rus.html записан успешно
# 2024-07-01 14:14:53.804 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/krasnodar_101.html записан успешно
# 2024-07-01 14:14:54.041 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/eu_rus_115.html записан успешно
# 2024-07-01 14:14:54.107 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/21jun2024/belyh_111.html записан успешно
# 2024-07-01 14:14:54.119 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/24jun2024/platan_127.html записан успешно
# 2024-07-01 14:14:54.479 | INFO     | __main__:get_async_job:189 - Обработка 2/4
# 2024-07-01 14:15:00.206 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/putin_202.html записан успешно
# 2024-07-01 14:15:00.209 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/nigeria_104.html записан успешно
# 2024-07-01 14:15:00.212 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/evan_117.html записан успешно
# 2024-07-01 14:15:00.215 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/le_parisien_004.html записан успешно
# 2024-07-01 14:15:00.218 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/ukr_war_107.html записан успешно
# 2024-07-01 14:15:00.220 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/canada_001.html записан успешно
# 2024-07-01 14:15:00.224 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/sev_202.html записан успешно
# 2024-07-01 14:15:00.226 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/dagestan_0014.html записан успешно
# 2024-07-01 14:15:00.228 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/ukr_war_108.html записан успешно
# 2024-07-01 14:15:00.231 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/mo810.html записан успешно
# 2024-07-01 14:15:00.232 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/germany_202.html записан успешно
# 2024-07-01 14:15:00.234 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/korea_202.html записан успешно
# 2024-07-01 14:15:00.235 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/france_109.html записан успешно
# 2024-07-01 14:15:00.243 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/assange_119.html записан успешно
# 2024-07-01 14:15:00.245 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/swiss_125.html записан успешно
# 2024-07-01 14:15:00.247 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/nato_115.html записан успешно
# 2024-07-01 14:15:00.249 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/ukr_war_109.html записан успешно
# 2024-07-01 14:15:00.253 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/derbent_202.html записан успешно
# 2024-07-01 14:15:00.255 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/ru_hamas_124.html записан успешно
# 2024-07-01 14:15:00.257 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/hodu_202.html записан успешно
# 2024-07-01 14:15:00.259 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/german_005.html записан успешно
# 2024-07-01 14:15:00.260 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/pa_202.html записан успешно
# 2024-07-01 14:15:00.262 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/ukr_war_106.html записан успешно
# 2024-07-01 14:15:00.264 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/harris_202.html записан успешно
# 2024-07-01 14:15:00.267 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/fr_202.html записан успешно
# 2024-07-01 14:15:00.268 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/assange_102.html записан успешно
# 2024-07-01 14:15:00.271 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/la_202.html записан успешно
# 2024-07-01 14:15:00.273 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/sev_201.html записан успешно
# 2024-07-01 14:15:00.275 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/terr805.html записан успешно
# 2024-07-01 14:15:00.277 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/min_ru_117.html записан успешно
# 2024-07-01 14:15:00.279 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/azov_108.html записан успешно
# 2024-07-01 14:15:00.283 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/satoty_202.html записан успешно
# 2024-07-01 14:15:00.285 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/dagestan_002.html записан успешно
# 2024-07-01 14:15:00.290 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/wilders_202.html записан успешно
# 2024-07-01 14:15:00.292 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/serbia809.html записан успешно
# 2024-07-01 14:15:00.294 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/bonn_501.html записан успешно
# 2024-07-01 14:15:00.296 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/israeli410.html записан успешно
# 2024-07-01 14:15:00.297 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/same821.html записан успешно
# 2024-07-01 14:15:00.299 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/min_ru_121.html записан успешно
# 2024-07-01 14:15:00.303 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/18jun2024/salvad_202.html записан успешно
# 2024-07-01 14:15:00.306 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/panama_202.html записан успешно
# 2024-07-01 14:15:00.309 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/dagestan_005.html записан успешно
# 2024-07-01 14:15:00.311 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/police_202.html записан успешно
# 2024-07-01 14:15:00.314 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/nigel_202.html записан успешно
# 2024-07-01 14:15:00.315 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/biden_202.html записан успешно
# 2024-07-01 14:15:00.318 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/pumpyansky.html записан успешно
# 2024-07-01 14:15:00.325 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/26jun2024/bolivia_0014.html записан успешно
# 2024-07-01 14:15:00.392 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/30jun2024/min_ru_131.html записан успешно
# 2024-07-01 14:15:00.395 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/23jun2024/min_ru_121.html записан успешно
# 2024-07-01 14:15:00.412 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/belgrad819.html записан успешно
# 2024-07-01 14:15:00.776 | INFO     | __main__:get_async_job:189 - Обработка 3/4
# 2024-07-01 14:15:04.916 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/julan_202.html записан успешно
# 2024-07-01 14:15:05.017 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/bolivia_108.html записан успешно
# 2024-07-01 14:15:05.021 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/navalny_116.html записан успешно
# 2024-07-01 14:15:05.024 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/ukr_war_106.html записан успешно
# 2024-07-01 14:15:05.027 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/min_ru_118.html записан успешно
# 2024-07-01 14:15:05.029 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/chomsky_101.html записан успешно
# 2024-07-01 14:15:05.032 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/kursk801.html записан успешно
# 2024-07-01 14:15:05.037 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/sud_rus_120.html записан успешно
# 2024-07-01 14:15:05.041 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/ukr_109.html записан успешно
# 2024-07-01 14:15:05.043 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/tver_110.html записан успешно
# 2024-07-01 14:15:05.045 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/france_202.html записан успешно
# 2024-07-01 14:15:05.046 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/israeli410.html записан успешно
# 2024-07-01 14:15:05.047 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/bastr803.html записан успешно
# 2024-07-01 14:15:05.049 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/canada_001.html записан успешно
# 2024-07-01 14:15:05.050 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/canada_202.html записан успешно
# 2024-07-01 14:15:05.051 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/abbas_ru_112.html записан успешно
# 2024-07-01 14:15:05.053 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/stonehenge_128.html записан успешно
# 2024-07-01 14:15:05.054 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/min_ru_119.html записан успешно
# 2024-07-01 14:15:05.055 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/cnn_debates_poll_109.html записан успешно
# 2024-07-01 14:15:05.057 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/blinken_202.html записан успешно
# 2024-07-01 14:15:05.058 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/icc_004.html записан успешно
# 2024-07-01 14:15:05.059 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/debates_202.html записан успешно
# 2024-07-01 14:15:05.061 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/belgrad819.html записан успешно
# 2024-07-01 14:15:05.062 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/mo810.html записан успешно
# 2024-07-01 14:15:05.063 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/assange_101.html записан успешно
# 2024-07-01 14:15:05.065 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/lviv_110.html записан успешно
# 2024-07-01 14:15:05.066 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/lazareva_126.html записан успешно
# 2024-07-01 14:15:05.068 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/br_202.html записан успешно
# 2024-07-01 14:15:05.069 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/tha_202.html записан успешно
# 2024-07-01 14:15:05.071 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/mask802.html записан успешно
# 2024-07-01 14:15:05.072 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/dagestan_116.html записан успешно
# 2024-07-01 14:15:05.073 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/biden_202.html записан успешно
# 2024-07-01 14:15:05.075 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/min_ru_116.html записан успешно
# 2024-07-01 14:15:05.076 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/dnepr816.html записан успешно
# 2024-07-01 14:15:05.078 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/eidelman801.html записан успешно
# 2024-07-01 14:15:05.079 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/ukr_war_107.html записан успешно
# 2024-07-01 14:15:05.080 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/serbia809.html записан успешно
# 2024-07-01 14:15:05.082 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/27jun2024/canada408.html записан успешно
# 2024-07-01 14:15:05.083 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/same821.html записан успешно
# 2024-07-01 14:15:05.084 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/vl_102.html записан успешно
# 2024-07-01 14:15:05.088 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/ger_202.html записан успешно
# 2024-07-01 14:15:05.090 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/ukr_war_107.html записан успешно
# 2024-07-01 14:15:05.091 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/terr805.html записан успешно
# 2024-07-01 14:15:05.092 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/ukr_war_108.html записан успешно
# 2024-07-01 14:15:05.127 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/pride_202.html записан успешно
# 2024-07-01 14:15:05.153 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/ukr_202.html записан успешно
# 2024-07-01 14:15:05.166 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/28jun2024/biden_trump_101.html записан успешно
# 2024-07-01 14:15:05.177 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/dw_limbourg_501.html записан успешно
# 2024-07-01 14:15:05.226 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/19jun2024/kndr_202.html записан успешно
# 2024-07-01 14:15:05.247 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/25jun2024/abu_marzouk_102.html записан успешно
# 2024-07-01 14:15:05.622 | INFO     | __main__:get_async_job:189 - Обработка 4/4
# 2024-07-01 14:15:07.557 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/29jun2024/ukr_war_109.html записан успешно
# 2024-07-01 14:15:07.601 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/flor_202.html записан успешно
# 2024-07-01 14:15:07.603 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/min_ru_112.html записан успешно
# 2024-07-01 14:15:07.607 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/ukr_104.html записан успешно
# 2024-07-01 14:15:07.610 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/cyprus_0014.html записан успешно
# 2024-07-01 14:15:07.614 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/anti_202.html записан успешно
# 2024-07-01 14:15:07.617 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/luizi_202.html записан успешно
# 2024-07-01 14:15:07.645 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/syria_202.html записан успешно
# 2024-07-01 14:15:07.690 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/rus_drones_105.html записан успешно
# 2024-07-01 14:15:07.735 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/aust_202.html записан успешно
# 2024-07-01 14:15:07.778 | INFO     | __main__:write_to_db:101 - https://www.newsru.co.il/world/20jun2024/ukr_war_103.html записан успешно
